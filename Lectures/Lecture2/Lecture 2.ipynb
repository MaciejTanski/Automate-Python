# %% [markdown]
# # Lecture 2
# Procedural and object oriented paradigms of programming.
# Procedural programing centers around developing procedures (functions) and passing data in between while performing programmed tasks. So in a sense data and functionality remain separated.
# With Object Oriented Programming (OOP) we create objects that merge data and functionality together, which should in principle allow for better code organization, limit code redundancy and give a more real life relation between program parts.
# Object Oriented Programing (OOP) in Python is based on a couple of concepts, we will now discuss:
# * Class and object
# * Methods and attributes
# * Encapsulation
# * Inheritance and polymorphism
#
# Note: OOP, allows to do some things in a more natural and understandable manner, but there should be limits to the excessive use. What I mean, it is good when it is good, and sometimes to much is just to much.

# %% [markdown]
# ## Class and object:
# Class defines a type. This type is ours, meaning we design it. A class can be treated as a recipe for creating objects. It defines what object has (data) and what it can do (methods). In Python creating a class is very simple:

# %%
class Cat:
    pass

# %% [markdown]
# We defined a class *Cat*, it has nothing (*pass*) for now. We can create a number of variables of type *Cat*:

# %%
a = Cat()
b = []
b.append(Cat())
b.append(a)
print(a)
print(b)

# %% [markdown]
# We created two *Cat* s and stored them in a `list` *b*. Note that `b[1]` is the same as *a*. Although right now our Cat class has no attributes, we might add those on the run. Which in a long run might not be such a good idea, but is possible, due to dynamic typing paradigm:

# %%
a.b = 10 # now object a of type Cat has an attribute b!

# %% [markdown]
# Still, this will not work:

# %%
print(b[0].b)

# %% [markdown]
# But this will (Why?):

# %%
print(b[1].b)

# %% [markdown]
# We will return to the "additional" attributes in a second to illustrate possible problems.
#
# **Coding time!**: In a separate file define a class Animal. Import the module here and create a list to store Animal objects.

# %%
import animal
...

# %% [markdown]
# ## Methods and attributes
# Classes define data an object of the class has. Let expand the Cat so it has a `breed` attribute. Let's make it a string:

# %%
class Cat:
    breed = ''

# %%
print(a.breed)

# %%
cat1 = Cat()
cat1.breed = 'Sjam'
cat2 = Cat()
cat2.breed = 'Persian'
# Let have cats in a cat list
clist = [cat1, cat2]

# %%
for c in clist:
    print(c.breed)

# %% [markdown]
# **Coding time**!: Extend Animal to include taxonomic information stored as a string. For now just phylum (typ). Create some objects of different phylum (check Wiki for possible choices).

# %%
class Animal:
    phylum = ''

# %% [markdown]
# ### self
# We will now add methods to perform some operation on the Cat object. Before we do we need to mention the **self** parameter. **self** is used to refer to the attributes of the object of the class, and is similar to the **C++** **this** pointer. It is also used to define that a procedure is a method of the class, by being the first (or the only) argument.

# %%
breed = 'ala ma kota'
class Cat:
    breed = ''
    
    def Print(self): # Note self as an argument!
        print('This cat is a', self.breed)

# %%
a = Cat()
a.breed = 'sjam'

# %%
a.Print()

# %% [markdown]
# Since we redefined the Cat class, we need to recreate the objects (check if the previous ones have method *Print()*):

# %%
cat1 = Cat()
cat1.breed = 'Sjam'
cat2 = Cat()
cat2.breed = 'Persian'
# Let have cats in a cat list
clist = [cat1, cat2]

# %%
for c in clist:
    c.Print()

# %% [markdown]
# **Coding time!**: Extend the Animal class to poses a method that returns the number of letters in the phylum (need a better idea). Test this method here.

# %% [markdown]
# ### Going back to additional attributes:
# Let's see some consequences of the additional attribute:

# %%
class Cat:
    def fun(self):
        print(self.b) # this Cat has no b!

# %%
a = Cat()
a.fun()

# %%
a.b = 0
print(a.b)
# but:
a.fun()

# %% [markdown]
# ### `__init__` method
# Is used to define a way to construct an object of the class. It is run the moment you create an object and can be used to create one based on some parameters. Our new cat will look like this:

# %%
class Cat:
    def __init__(self):
        self.breed = 'no breed'
        self.color = 'no colour'
        self.age = 'old'
    def Print(self):
        print('This', self.breed, 'cat is', self.color, 'and is', self.age, 'years old')

# %%
a = Cat()
a.Print()

# %%
class Cat:
    def __init__(self):
        self.breed = 'no breed'
        self.color = 'no colour'
        self.age = 'old'
#     def __init__(self, b, c, a): # Uncomment and see below
#         self.breed = b
#         self.color = c
#         self.age = a
    def Print(self):
        print('This', self.breed, 'cat is', self.color, 'and is', self.age, 'years old')

# %%
a = Cat()

# %%
class Cat:
    def __init__(self, b, c, a):
        self.breed = b
        self.color = c
        self.age = a
    def Print(self):
        print('This', self.breed, 'cat is', self.color, 'and is', self.age, 'years old')

# %%
a = Cat('Sjam', 'black', 10)
a.Print()

# %% [markdown]
# **Coding time!**: Add **__init__(self, ...)** method to the Animal. Set phylum and test it here by creating some Animal objects.

# %%
class Animal:
    phylum = 'not defined'
    __isextinct = 'No' # ??

    def __init__(self, phy):
        self.phylum = phy

# %% [markdown]
# ## Encapsulation or hermetization
# One of the crucial concepts in OPP is encapsulation or hermetization. That is the ability to limit access to some of the object's attributes and making them unavailable for modification or even reading. Various languages offer different levels at which such restriction is possible (e.g. **C++** has a sophisticated suite of possibilities). In Python this is limited to a naming convention. Any attribute that starts with \_\_ (two low bars?) is restricted. Let's see an example of a Cat's bowl, that we are going to make unavailable:

# %%
class Cat:
    def __init__(self):
        self.__bowl = 'empty' # cats have bowls with food
    def FillBowl(self):
        self.__bowl = "Filled with food"
    def Eat(self):
        self.__bowl = 'empty'
    def Print(self):
        print(self.__bowl)
        cathappy = "Cat is happy" if self.__bowl != 'empty' else "Cat is sad"
        print(cathappy)

# %%
a = Cat()
a.FillBowl()

# %%
print(a.__bowl)

# %%
a.Print()

# %%
a.__bowl = 'empty'

# %%
print(a.__bowl)

# %%
a.Print()

# %%
a.Eat()
a.Print()

# %% [markdown]
# We note that we can not access Cat's bowl for reading (AttributeError),
# and if we try to assign to it it has no effect on the attribute.

# %% [markdown]
# **Coding time!**: Extend the Animal class to contain a private member variable. This variable could be a string describing if the animal exists presently or is extinct. Add Methods, to read (get) write (set) this variable, and test those here.

# %% [markdown]
# ## Inheritance and polymorphism

# %% [markdown]
# Inheritance is central to OOP. The concept is based on extending functionality of existing classes by deriving from them new ones, that conceptually perform similar, but more specific tasks. So inheritance introduces hierarchy to classes form abstract concepts (such as a general shape in geometry) down to very specific ones (for shapes, a square or a triangle, etc.).
#
# The class that is more abstract, from which we derive is called the **base** class (general shape), and the less abstract class formed via inheritance is the **derived** one (a square is less general than a shape, so it could be derived from it).
#
# Concept of inheritance allows for:
# * Less code, since code is reused
# * Possibly more order in the code
# * Polymorphism, i.e. handling objects in a unified way
#
# Let us present the concept with
#
# ```sequence
# Mammal<-Dog
#       <-Cat
# ```
# Note: Show step-by-step, not all at once:

# %%
class Mammal():
    def __init__(self):
        self.drinks_milk = 'Yes'

# %%
class Cat(Mammal):
    pass
class Dog(Mammal):
    pass

# %% [markdown]
# Finally we get something like this:

# %%
class Mammal():
    def __init__(self, n):
        self.name = n
        self.drinks_milk = "Yes"
    def make_noise(self): # all derived classes make noise 
        print(self.noise)
    def print_name(self):
        print('Has no name')

# %%
class Cat(Mammal):
    def __init__(self):
        self.noise = "Meow"
        Mammal.__init__(self, "Cat")
    def print_name(self):
        print('Behemoth')

# %%
class Dog(Mammal):
    def __init__(self):
        self.noise = "Bark"
        Mammal.__init__(self, "Cat")
    def print_name(self):
        print('Cerberus')

# %%
m = Mammal('')
print(m.drinks_milk)
m.print_name()
# m.make_noise()

# %%
c = Cat()
print(c.drinks_milk)
c.print_name()
c.make_noise()

# %%
d = Dog()
print(c.drinks_milk)
d.print_name()
d.make_noise()

# %% [markdown]
# **Coding time!**: Extend the Animal class to be base for Cat and Dog via Mammal class. Add Reptiles to go along with mammals and some derived classes that inherit from a reptile. In the end you should be able to create objects of 4 different classes.

# %% [markdown]
# # isinstance vs type
# Sometimes there is a need to verify a type of an object. In OOP inheritance is based on the derived type extending the base one. This can be understood that the derived type object is the base and some more.
# Sometimes one might need to check if a class or an object of a class are of specific type, or inherit from one.
#
# * `type(obj)` returns the type of an object. Can be used with `is` to check if object is of specific type. Does not work on inheritance.
# * `isinstance(obj, type)` returns true if an object is derived from a class passed as an argument. Works on inheritance.
# * `issubclass(type1, type2)` Works on types, not objects. Checks if a class has been derived from the base class.
#
# Let's see in an example

# %%
class Animal:
    phylum = 'not defined'
    __isextinct = 'No' # ??

    def __init__(self, phy):
        self.phylum = phy

    def no_letters(self):
        return len(self.phylum)-1

    def SetExtinct(self, val):
        self.__isextinct = val
    def GetExtinct(self):
        return self.__isextinct

    def IsWarm(self):
        return self.isWarm

# %%
class Mamal(Animal):
    isWarm = 'Yes'
    def __init__(self):
        Animal.__init__(self, 'ssaki')

class Reptile(Animal):
    isWarm = 'No'
    def __init__(self):
        Animal.__init__(self, 'gady')

# %%
class Dog(Mamal):
    def __init__(self):
        Mamal.__init__(self)

class Cat(Mamal):
    def __init__(self):
        Mamal.__init__(self)

class Snake(Reptile):
    def __init__(self):
        Reptile.__init__(self)

class Lizard(Reptile):
    def __init__(self):
        Reptile.__init__(self)

# %%
dog = Dog()
cat = Cat()
snake = Snake()
viper = Snake()
lizard = Lizard()

# %% [markdown]
# `type(obj)`

# %%
print(type(dog))
print(type(snake))

# %%
print(type(dog) is Dog)
print(type(snake) is Dog)

# %%
print(type(dog) is Mamal)
print(type(snake) is Reptile)
print(type(snake) is Animal)

# %% [markdown]
# `isinstance(obj, type)`

# %%
print(isinstance(cat, Animal))
print(isinstance(cat, Mamal))
print(isinstance(cat, Reptile))
print(isinstance(cat, Cat))

# %%
print(isinstance(snake, Animal))
print(isinstance(snake, Mamal))
print(isinstance(snake, Reptile))
print(isinstance(snake, Cat))
print(isinstance(snake, Lizard))

# %%
print(isinstance(viper, type(snake)))

# %%
print(issubclass(Cat, Animal))
print(issubclass(Cat, Mamal))
print(issubclass(Cat, Reptile))
print(issubclass(Cat, (Reptile, Dog, Mamal)))

# %%
print(type(dog) is Dog)
print(type(cat) is Mamal)
print(type(snake) is Animal)
print(type(lizard) is Lizard)

# %% [markdown]
# ### Some operations on lists
# Since we are now able to create objects to contain both the data and procedures, we will try to experiment with operations on lists that concern lists of objects.
#
# We will try to use some new concepts as well:
# * `filter()`
# * `sort()` with `lambda`
#
# 1. Make a function that generates an animal of a random type.
# 2. Create a number of cats, dogs and snakes of various ages.
# 3. Put them all in a list and filter according to various criteria.
#
# Use
# ```
# import random
# print(random.randint(0, 9))
# ```
# To generate random behavior.

# %%
from animal import *
import random

# %%
print(random.randint(0, 3))
# Out:
# 2

# %% [markdown]
# A function that makes a random animal:

# %%
def AnimalFarm():
    a = random.randint(0,3)
    if a == 0:
        return Cat()
    elif a == 1:
        return Dog()
    elif a == 2:
        return Snake()
    else:
        return Lizard()

# %%
alist = []
for i in range(0,100):
    alist.append(AnimalFarm())

# %% [markdown]
# or

# %%
alist = [AnimalFarm() for i in range(0,100)]

# %%
for a in alist:
    print(a, type(a), isinstance(a, Reptile))
# Out:
# <animal.Snake object at 0x7f3af0763c40> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af0763490> <class 'animal.Dog'> False
# <animal.Cat object at 0x7f3af076ba30> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af076b9d0> <class 'animal.Lizard'> True
# <animal.Cat object at 0x7f3af076b8b0> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af076b850> <class 'animal.Lizard'> True
# <animal.Cat object at 0x7f3af076b7f0> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af076b790> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af076b700> <class 'animal.Cat'> False
# <animal.Snake object at 0x7f3af076b910> <class 'animal.Snake'> True
# <animal.Cat object at 0x7f3af076ba60> <class 'animal.Cat'> False
# <animal.Dog object at 0x7f3af076bac0> <class 'animal.Dog'> False
# <animal.Cat object at 0x7f3af076bb20> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af076bb80> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af076bc70> <class 'animal.Lizard'> True
# <animal.Snake object at 0x7f3af076bcd0> <class 'animal.Snake'> True
# <animal.Lizard object at 0x7f3af076bd30> <class 'animal.Lizard'> True
# <animal.Cat object at 0x7f3af076bd90> <class 'animal.Cat'> False
# <animal.Snake object at 0x7f3af076bdf0> <class 'animal.Snake'> True
# <animal.Cat object at 0x7f3af076be50> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af076beb0> <class 'animal.Lizard'> True
# <animal.Cat object at 0x7f3af076bf10> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af076bf70> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af076bfd0> <class 'animal.Cat'> False
# <animal.Snake object at 0x7f3af076ae90> <class 'animal.Snake'> True
# <animal.Lizard object at 0x7f3af076bc40> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af076aef0> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af076af50> <class 'animal.Snake'> True
# <animal.Cat object at 0x7f3af076b1c0> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af076b040> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af076b400> <class 'animal.Cat'> False
# <animal.Dog object at 0x7f3af076b460> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af07728f0> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af07714e0> <class 'animal.Dog'> False
# <animal.Dog object at 0x7f3af07716c0> <class 'animal.Dog'> False
# <animal.Lizard object at 0x7f3af07718a0> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af0771a80> <class 'animal.Dog'> False
# <animal.Lizard object at 0x7f3af0771c60> <class 'animal.Lizard'> True
# <animal.Cat object at 0x7f3af07720b0> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af07722f0> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af07724d0> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af07726e0> <class 'animal.Dog'> False
# <animal.Cat object at 0x7f3af0770040> <class 'animal.Cat'> False
# <animal.Snake object at 0x7f3af07700a0> <class 'animal.Snake'> True
# <animal.Cat object at 0x7f3af0770100> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af0770160> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af07701c0> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af0770220> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af0770280> <class 'animal.Dog'> False
# <animal.Dog object at 0x7f3af07702e0> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af0770340> <class 'animal.Snake'> True
# <animal.Cat object at 0x7f3af07703a0> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af0770400> <class 'animal.Lizard'> True
# <animal.Cat object at 0x7f3af0770460> <class 'animal.Cat'> False
# <animal.Dog object at 0x7f3af07704c0> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af0770520> <class 'animal.Snake'> True
# <animal.Snake object at 0x7f3af0770580> <class 'animal.Snake'> True
# <animal.Cat object at 0x7f3af07705e0> <class 'animal.Cat'> False
# <animal.Snake object at 0x7f3af0770640> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af07706a0> <class 'animal.Dog'> False
# <animal.Dog object at 0x7f3af0770700> <class 'animal.Dog'> False
# <animal.Lizard object at 0x7f3af0770760> <class 'animal.Lizard'> True
# <animal.Lizard object at 0x7f3af07707c0> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af0770820> <class 'animal.Dog'> False
# <animal.Lizard object at 0x7f3af0770880> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af07708e0> <class 'animal.Dog'> False
# <animal.Dog object at 0x7f3af0770940> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af07709a0> <class 'animal.Snake'> True
# <animal.Lizard object at 0x7f3af0770a00> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af0770a60> <class 'animal.Dog'> False
# <animal.Dog object at 0x7f3af0770ac0> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af0770b20> <class 'animal.Snake'> True
# <animal.Lizard object at 0x7f3af0770b80> <class 'animal.Lizard'> True
# <animal.Snake object at 0x7f3af0770be0> <class 'animal.Snake'> True
# <animal.Snake object at 0x7f3af0770c70> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af0770cd0> <class 'animal.Dog'> False
# <animal.Dog object at 0x7f3af0770d30> <class 'animal.Dog'> False
# <animal.Dog object at 0x7f3af0770d90> <class 'animal.Dog'> False
# <animal.Lizard object at 0x7f3af0770df0> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af0770e50> <class 'animal.Dog'> False
# <animal.Cat object at 0x7f3af0770ee0> <class 'animal.Cat'> False
# <animal.Dog object at 0x7f3af0770f40> <class 'animal.Dog'> False
# <animal.Cat object at 0x7f3af0770fa0> <class 'animal.Cat'> False
# <animal.Snake object at 0x7f3af0771000> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af0771060> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af07710c0> <class 'animal.Snake'> True
# <animal.Snake object at 0x7f3af0771120> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af0771180> <class 'animal.Dog'> False
# <animal.Lizard object at 0x7f3af07711e0> <class 'animal.Lizard'> True
# <animal.Cat object at 0x7f3af0771240> <class 'animal.Cat'> False
# <animal.Cat object at 0x7f3af07712a0> <class 'animal.Cat'> False
# <animal.Snake object at 0x7f3af0771300> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af0771360> <class 'animal.Dog'> False
# <animal.Snake object at 0x7f3af07713c0> <class 'animal.Snake'> True
# <animal.Lizard object at 0x7f3af0771420> <class 'animal.Lizard'> True
# <animal.Snake object at 0x7f3af0771480> <class 'animal.Snake'> True
# <animal.Dog object at 0x7f3af077d5a0> <class 'animal.Dog'> False
# <animal.Cat object at 0x7f3af077d600> <class 'animal.Cat'> False
# <animal.Lizard object at 0x7f3af077d660> <class 'animal.Lizard'> True
# <animal.Dog object at 0x7f3af077d6c0> <class 'animal.Dog'> False

# %%
mlist = list(filter(lambda l: type(l) is Dog or type(l) is Cat, alist))
print(mlist)

# %%
mlist = list(filter(lambda l: isinstance(l, Mamal), alist))
print(mlist)

# %%
a = [range(0,10)]
print(a)

# %%
a = [x for x in range(0,10)]
print(a)

# %%
b = list(filter(lambda l: l>5, a))

# %%
print(b)
